# %% [markdown]
# # Importing libraries

# %%
#pip install gspread oauth2client df2gspread

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
scope=['https://www.googleapis.com/auth/drive']
credentials=ServiceAccountCredentials.from_json_keyfile_name('milestone1.json',scope)
client=gspread.authorize(credentials)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import smtplib
import config
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Sheet data to Dataframe

# %%
sheet=client.open_by_url("https://docs.google.com/spreadsheets/d/1HYjfEe3aCbufbqIXKs0Xz-gfoQNztGhCN1ivx0gZXnc/edit#gid=0")

# %%
idt=[]
task=[]
date=[]
module=[]
task_type=[]
student=[]
late_submission=[]
points=[]
total=[]
task_winner=[]
for i in sheet:
    data=i.get_all_records()
    for item in data:
        i=item['id']
        idt.append(i)
        t=item['Task']
        task.append(t)
        d=item['Date']
        date.append(d)
        m=item['Module']
        module.append(m)
        tp=item['Type']
        task_type.append(tp)
        s=item['Student']
        student.append(s)
        ls=item['Late Submission']
        late_submission.append(ls)
        pts=item['Points']
        points.append(pts)
        tot=item['Total']
        total.append(tot)
        tw=item['Task Winner']
        task_winner.append(tw)

# %%
df_list={}
df_list['Id']=idt
df_list['Task']=task
df_list['Date']=date
df_list['Module']=module
df_list['Type']=task_type
df_list['Student']=student
df_list['Late Submission']=late_submission
df_list['Points']=points
df_list['Total']=total
df_list['Task Winner']=task_winner
df= pd.DataFrame(data=df_list)

# %%
df
# Out:
#       Id                            Task                Date  \
# 0      1  Linkedin Profile create/update           7/22/2019
# 1      1  Linkedin Profile create/update           7/22/2019
# 2      1  Linkedin Profile create/update           7/22/2019
# 3      1  Linkedin Profile create/update           7/22/2019
# 4      1  Linkedin Profile create/update           7/22/2019
# 5      1  Linkedin Profile create/update           7/22/2019
# 6      1  Linkedin Profile create/update           7/22/2019
# 7      1  Linkedin Profile create/update           7/22/2019
# 8      1  Linkedin Profile create/update           7/22/2019
# 9      1  Linkedin Profile create/update           7/22/2019
# 10     1  Linkedin Profile create/update           7/22/2019
# 11     1  Linkedin Profile create/update           7/22/2019
# 12     1  Linkedin Profile create/update           7/22/2019
# 13     1  Linkedin Profile create/update           7/22/2019
# 14     1  Linkedin Profile create/update           7/22/2019
# 15     1  Linkedin Profile create/update           7/22/2019
# 16     1  Linkedin Profile create/update           7/22/2019
# 17     1  Linkedin Profile create/update           7/22/2019
# 18     1  Linkedin Profile create/update           7/22/2019
# 19     1  Linkedin Profile create/update           7/22/2019
# 20     1  Linkedin Profile create/update           7/22/2019
# 21     1  Linkedin Profile create/update           7/22/2019
# 22     1  Linkedin Profile create/update           7/22/2019
# 23     0                     Ajkyaukhada           7/22/2019
# 24     0                     Ajkyaukhada           7/22/2019
# 25     0                     Ajkyaukhada           7/22/2019
# 26     0                     Ajkyaukhada           7/22/2019
# 27     0                     Ajkyaukhada           7/22/2019
# 28     0                     Ajkyaukhada           7/22/2019
# 29     0                     Ajkyaukhada           7/22/2019
# ...   ..                             ...                 ...
# 1513   0                     AjKyaUkhada           9/24/2019
# 1514   0                     AjKyaUkhada           9/24/2019
# 1515   0                     AjKyaUkhada           9/24/2019
# 1516   0                     AjKyaUkhada           9/24/2019
# 1517   0                     AjKyaUkhada           9/24/2019
# 1518   0                     AjKyaUkhada           9/24/2019
# 1519   0                     AjKyaUkhada           9/24/2019
# 1520   0                     AjKyaUkhada           9/24/2019
# 1521   0                     AjKyaUkhada           9/24/2019
# 1522   0                     AjKyaUkhada           9/24/2019
# 1523   0                     AjKyaUkhada           9/24/2019
# 1524   0                     AjKyaUkhada           9/24/2019
# 1525   0               Knowledge Sharing           9/25/2019
# 1526   0                     AjKyaUkhada           9/25/2019
# 1527   0                     AjKyaUkhada           9/25/2019
# 1528   0                     AjKyaUkhada           9/25/2019
# 1529   0                     AjKyaUkhada           9/25/2019
# 1530   0                     AjKyaUkhada           9/25/2019
# 1531   0                     AjKyaUkhada           9/25/2019
# 1532   0                     AjKyaUkhada           9/25/2019
# 1533   0                     AjKyaUkhada           9/25/2019
# 1534   0                     AjKyaUkhada           9/25/2019
# 1535   0                     AjKyaUkhada           9/25/2019
# 1536   0                     AjKyaUkhada           9/25/2019
# 1537   0                     AjKyaUkhada           9/25/2019
# 1538   0                     AjKyaUkhada           9/25/2019
# 1539   0                     AjKyaUkhada           9/25/2019
# 1540   0                     AjKyaUkhada           9/25/2019
# 1541   0                     AjKyaUkhada  2019-09-19 6:33:21
# 1542   0                     AjKyaUkhada  2019-09-19 7:16:34
#
#                 Module                        Type       Student  \
# 0     Profile Building  Intent, Creativity,Content     Chandrima
# 1     Profile Building  Intent, Creativity,Content         Dipam
# 2     Profile Building  Intent, Creativity,Content         Durga
# 3     Profile Building  Intent, Creativity,Content       Kaushal
# 4     Profile Building  Intent, Creativity,Content          Arya
# 5     Profile Building  Intent, Creativity,Content         Kunal
# 6     Profile Building  Intent, Creativity,Content       Prasoon
# 7     Profile Building  Intent, Creativity,Content       Purbita
# 8     Profile Building  Intent, Creativity,Content       Roumyak
# 9     Profile Building  Intent, Creativity,Content        Shakib
# 10    Profile Building  Intent, Creativity,Content       Sharika
# 11    Profile Building  Intent, Creativity,Content  Siddhishikha
# 12    Profile Building  Intent, Creativity,Content      Swaastik
# 13    Profile Building  Intent, Creativity,Content       Surabhi
# 14    Profile Building  Intent, Creativity,Content      Ujjainee
# 15    Profile Building  Intent, Creativity,Content        Vishal
# 16    Profile Building  Intent, Creativity,Content         Wrick
# 17    Profile Building  Intent, Creativity,Content        Apurwa
# 18    Profile Building  Intent, Creativity,Content        Sonali
# 19    Profile Building  Intent, Creativity,Content      Shantanu
# 20    Profile Building  Intent, Creativity,Content     Sudhanshu
# 21    Profile Building  Intent, Creativity,Content        Anjali
# 22    Profile Building  Intent, Creativity,Content        Bhavna
# 23              Ritual                 Consistency       Prasoon
# 24              Ritual                 Consistency         Kunal
# 25              Ritual                 Consistency       Purbita
# 26              Ritual                 Consistency  Siddhishikha
# 27              Ritual                 Consistency         Durga
# 28              Ritual                 Consistency       Surabhi
# 29              Ritual                 Consistency        Shakib
# ...                ...                         ...           ...
# 1513            Ritual                 Consistency       Surabhi
# 1514            Ritual                 Consistency         Kunal
# 1515            Ritual                 Consistency     Chandrima
# 1516            Ritual                 Consistency         Durga
# 1517            Ritual                 Consistency        Anjali
# 1518            Ritual                 Consistency        Shakib
# 1519            Ritual                 Consistency       Prasoon
# 1520            Ritual                 Consistency        Vishal
# 1521            Ritual                 Consistency         Dipam
# 1522            Ritual                 Consistency      Shantanu
# 1523            Ritual                 Consistency        Apurwa
# 1524            Ritual                 Consistency        Bhavna
# 1525            Ritual       Consistency,Curiosity      Ujjainee
# 1526            Ritual                 Consistency     Swaastick
# 1527            Ritual                 Consistency        Sonali
# 1528            Ritual                 Consistency     Chandrima
# 1529            Ritual                 Consistency       Purbita
# 1530            Ritual                 Consistency         Kunal
# 1531            Ritual                 Consistency      Ujjainee
# 1532            Ritual                 Consistency         Dipam
# 1533            Ritual                 Consistency       Kaushal
# 1534            Ritual                 Consistency       Surabhi
# 1535            Ritual                 Consistency          Arya
# 1536            Ritual                 Consistency         Durga
# 1537            Ritual                 Consistency        Shakib
# 1538            Ritual                 Consistency      Shantanu
# 1539            Ritual                 Consistency        Bhavna
# 1540            Ritual                 Consistency        Anjali
# 1541            Ritual                 Consistency       Roumyak
# 1542            Ritual                 Consistency        Apurwa
#
#       Late Submission  Points  Total  Task Winner
# 0                   0     6.0     10            0
# 1                   0     7.0     10            0
# 2                   0     6.0     10            0
# 3                   0     7.0     10            0
# 4                   0     6.0     10            0
# 5                   0     8.0     10            0
# 6                   0     5.0     10            0
# 7                   0     6.0     10            0
# 8                   0     6.0     10            0
# 9                   0     6.0     10            0
# 10                  1     6.5     10            0
# 11                  0     6.0     10            0
# 12                  0     7.5     10            1
# 13                  0     6.0     10            0
# 14                  0     7.0     10            0
# 15                  0     6.0     10            0
# 16                  0     6.0     10            0
# 17                  1     6.0     10            0
# 18                  1     6.5     10            0
# 19                  0     7.0     10            0
# 20                  1     6.5     10            0
# 21                  0     7.0     10            0
# 22                  0     9.0     10            0
# 23                  0     2.0      2            0
# 24                  0     2.0      2            0
# 25                  0     2.0      2            0
# 26                  0     2.0      2            0
# 27                  0     2.0      2            0
# 28                  0     2.0      2            0
# 29                  0     2.0      2            0
# ...               ...     ...    ...          ...
# 1513                0     1.0      1            0
# 1514                0     1.0      1            0
# 1515                0     1.0      1            0
# 1516                0     1.0      1            0
# 1517                0     1.0      1            0
# 1518                0     1.0      1            0
# 1519                0     1.0      1            0
# 1520                0     1.0      1            0
# 1521                0     1.0      1            0
# 1522                0     1.0      1            0
# 1523                0     1.0      1            0
# 1524                0     1.0      1            0
# 1525                0     1.0      1            0
# 1526                0     1.0      1            0
# 1527                0     1.0      1            0
# 1528                0     1.0      1            0
# 1529                0     1.0      1            0
# 1530                0     1.0      1            0
# 1531                0     1.0      1            0
# 1532                0     1.0      1            0
# 1533                0     1.0      1            0
# 1534                0     1.0      1            0
# 1535                0     1.0      1            0
# 1536                0     1.0      1            0
# 1537                0     1.0      1            0
# 1538                0     1.0      1            0
# 1539                0     1.0      1            0
# 1540                0     1.0      1            0
# 1541                0     1.0      1            0
# 1542                0     1.0      1            0
#
# [1543 rows x 10 columns]

# %% [markdown]
# # Data Cleaning

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
def analysis_date_range(start_date,end_date):
    mask=df[(df['Date']>start_date) & (df['Date']<end_date)]
    return mask

# %%
new_df=analysis_date_range('2019-01-01','2019-09-16')

# %%
new_df
# Out:
#       Id                                    Task                Date  \
# 0      1          Linkedin Profile create/update 2019-07-22 00:00:00
# 1      1          Linkedin Profile create/update 2019-07-22 00:00:00
# 2      1          Linkedin Profile create/update 2019-07-22 00:00:00
# 3      1          Linkedin Profile create/update 2019-07-22 00:00:00
# 4      1          Linkedin Profile create/update 2019-07-22 00:00:00
# 5      1          Linkedin Profile create/update 2019-07-22 00:00:00
# 6      1          Linkedin Profile create/update 2019-07-22 00:00:00
# 7      1          Linkedin Profile create/update 2019-07-22 00:00:00
# 8      1          Linkedin Profile create/update 2019-07-22 00:00:00
# 9      1          Linkedin Profile create/update 2019-07-22 00:00:00
# 10     1          Linkedin Profile create/update 2019-07-22 00:00:00
# 11     1          Linkedin Profile create/update 2019-07-22 00:00:00
# 12     1          Linkedin Profile create/update 2019-07-22 00:00:00
# 13     1          Linkedin Profile create/update 2019-07-22 00:00:00
# 14     1          Linkedin Profile create/update 2019-07-22 00:00:00
# 15     1          Linkedin Profile create/update 2019-07-22 00:00:00
# 16     1          Linkedin Profile create/update 2019-07-22 00:00:00
# 17     1          Linkedin Profile create/update 2019-07-22 00:00:00
# 18     1          Linkedin Profile create/update 2019-07-22 00:00:00
# 19     1          Linkedin Profile create/update 2019-07-22 00:00:00
# 20     1          Linkedin Profile create/update 2019-07-22 00:00:00
# 21     1          Linkedin Profile create/update 2019-07-22 00:00:00
# 22     1          Linkedin Profile create/update 2019-07-22 00:00:00
# 23     0                             Ajkyaukhada 2019-07-22 00:00:00
# 24     0                             Ajkyaukhada 2019-07-22 00:00:00
# 25     0                             Ajkyaukhada 2019-07-22 00:00:00
# 26     0                             Ajkyaukhada 2019-07-22 00:00:00
# 27     0                             Ajkyaukhada 2019-07-22 00:00:00
# 28     0                             Ajkyaukhada 2019-07-22 00:00:00
# 29     0                             Ajkyaukhada 2019-07-22 00:00:00
# ...   ..                                     ...                 ...
# 1248   0                             AjKyaUkhada 2019-09-14 20:37:18
# 1249   0                             AjKyaUkhada 2019-09-14 21:19:25
# 1250   0                             AjKyaUkhada 2019-09-14 21:24:19
# 1251   0                             AjKyaUkhada 2019-09-14 22:55:47
# 1252   0                             AjKyaUkhada 2019-09-15 08:10:58
# 1253   0                             AjKyaUkhada 2019-09-15 08:13:48
# 1254   0                             AjKyaUkhada 2019-09-15 10:54:07
# 1255   0                             AjKyaUkhada 2019-09-15 11:49:48
# 1256   0                             AjKyaUkhada 2019-09-15 15:30:56
# 1257   0                       Knowledge Sharing 2019-09-15 15:32:37
# 1258   0                             AjKyaUkhada 2019-09-15 15:33:14
# 1259   0                             AjKyaUkhada 2019-09-15 15:33:41
# 1260   0                             AjKyaUkhada 2019-09-15 15:52:31
# 1261   0                             AjKyaUkhada 2019-09-15 15:54:07
# 1262   0                             AjKyaUkhada 2019-09-15 16:26:18
# 1263   0                             AjKyaUkhada 2019-09-15 16:33:42
# 1264   0                             AjKyaUkhada 2019-09-15 16:51:47
# 1265   0                             AjKyaUkhada 2019-09-15 17:21:26
# 1266   0                             AjKyaUkhada 2019-09-15 17:29:29
# 1267   0                             AjKyaUkhada 2019-09-15 17:46:25
# 1268   0                             AjKyaUkhada 2019-09-15 18:07:05
# 1269   0                             AjKyaUkhada 2019-09-15 18:08:22
# 1270   0                             AjKyaUkhada 2019-09-15 21:01:53
# 1271   0                             AjKyaUkhada 2019-09-15 21:12:22
# 1391   8                 Github Profile Creation 2019-08-13 00:00:00
# 1392   3  Blog on Different data based job roles 2019-07-30 00:00:00
# 1393   9           Blog on Data Analysis Process 2019-08-23 00:00:00
# 1394   9           Blog on Data Analysis Process 2019-08-23 00:00:00
# 1395  12                            Web Scraping 2019-09-11 00:00:00
# 1396  12                            Web Scraping 2019-09-11 00:00:00
#
#                             Module  \
# 0                 Profile Building
# 1                 Profile Building
# 2                 Profile Building
# 3                 Profile Building
# 4                 Profile Building
# 5                 Profile Building
# 6                 Profile Building
# 7                 Profile Building
# 8                 Profile Building
# 9                 Profile Building
# 10                Profile Building
# 11                Profile Building
# 12                Profile Building
# 13                Profile Building
# 14                Profile Building
# 15                Profile Building
# 16                Profile Building
# 17                Profile Building
# 18                Profile Building
# 19                Profile Building
# 20                Profile Building
# 21                Profile Building
# 22                Profile Building
# 23                          Ritual
# 24                          Ritual
# 25                          Ritual
# 26                          Ritual
# 27                          Ritual
# 28                          Ritual
# 29                          Ritual
# ...                            ...
# 1248                        Ritual
# 1249                        Ritual
# 1250                        Ritual
# 1251                        Ritual
# 1252                        Ritual
# 1253                        Ritual
# 1254                        Ritual
# 1255                        Ritual
# 1256                        Ritual
# 1257                        Ritual
# 1258                        Ritual
# 1259                        Ritual
# 1260                        Ritual
# 1261                        Ritual
# 1262                        Ritual
# 1263                        Ritual
# 1264                        Ritual
# 1265                        Ritual
# 1266                        Ritual
# 1267                        Ritual
# 1268                        Ritual
# 1269                        Ritual
# 1270                        Ritual
# 1271                        Ritual
# 1391              Profile Building
# 1392  Introduction to Data Science
# 1393                Data Analytics
# 1394                Data Analytics
# 1395                Data Analytics
# 1396                Data Analytics
#
#                                                    Type       Student  \
# 0                            Intent, Creativity,Content     Chandrima
# 1                            Intent, Creativity,Content         Dipam
# 2                            Intent, Creativity,Content         Durga
# 3                            Intent, Creativity,Content       Kaushal
# 4                            Intent, Creativity,Content          Arya
# 5                            Intent, Creativity,Content         Kunal
# 6                            Intent, Creativity,Content       Prasoon
# 7                            Intent, Creativity,Content       Purbita
# 8                            Intent, Creativity,Content       Roumyak
# 9                            Intent, Creativity,Content        Shakib
# 10                           Intent, Creativity,Content       Sharika
# 11                           Intent, Creativity,Content  Siddhishikha
# 12                           Intent, Creativity,Content      Swaastik
# 13                           Intent, Creativity,Content       Surabhi
# 14                           Intent, Creativity,Content      Ujjainee
# 15                           Intent, Creativity,Content        Vishal
# 16                           Intent, Creativity,Content         Wrick
# 17                           Intent, Creativity,Content        Apurwa
# 18                           Intent, Creativity,Content        Sonali
# 19                           Intent, Creativity,Content      Shantanu
# 20                           Intent, Creativity,Content     Sudhanshu
# 21                           Intent, Creativity,Content        Anjali
# 22                           Intent, Creativity,Content        Bhavna
# 23                                          Consistency       Prasoon
# 24                                          Consistency         Kunal
# 25                                          Consistency       Purbita
# 26                                          Consistency  Siddhishikha
# 27                                          Consistency         Durga
# 28                                          Consistency       Surabhi
# 29                                          Consistency        Shakib
# ...                                                 ...           ...
# 1248                                        Consistency       Roumyak
# 1249                                        Consistency      Shantanu
# 1250                                        Consistency        Bhavna
# 1251                                        Consistency       Prasoon
# 1252                                        Consistency        Sonali
# 1253                                        Consistency          Arya
# 1254                                        Consistency        Apurwa
# 1255                                        Consistency     Swaastick
# 1256                                        Consistency       Purbita
# 1257                              Consistency,Curiosity       Surabhi
# 1258                                        Consistency         Kunal
# 1259                                        Consistency       Surabhi
# 1260                                        Consistency      Ujjainee
# 1261                                        Consistency  Siddhishikha
# 1262                                        Consistency         Durga
# 1263                                        Consistency         Dipam
# 1264                                        Consistency       Prasoon
# 1265                                        Consistency     Chandrima
# 1266                                        Consistency        Anjali
# 1267                                        Consistency      Shantanu
# 1268                                        Consistency        Shakib
# 1269                                        Consistency        Vishal
# 1270                                        Consistency       Kaushal
# 1271                                        Consistency        Bhavna
# 1391                                Sincerity,Hard-work        Anjali
# 1392  Knowledge,Understanding,Communication,Analytic...        Anjali
# 1393                 Analysis, communication, sincerity        Anjali
# 1394                 Analysis, communication, sincerity        Bhavna
# 1395                                 Knowledge,Patience        Bhavna
# 1396                                 Knowledge,Patience  Siddhishikha
#
#       Late Submission  Points  Total  Task Winner
# 0                   0     6.0     10            0
# 1                   0     7.0     10            0
# 2                   0     6.0     10            0
# 3                   0     7.0     10            0
# 4                   0     6.0     10            0
# 5                   0     8.0     10            0
# 6                   0     5.0     10            0
# 7                   0     6.0     10            0
# 8                   0     6.0     10            0
# 9                   0     6.0     10            0
# 10                  1     6.5     10            0
# 11                  0     6.0     10            0
# 12                  0     7.5     10            1
# 13                  0     6.0     10            0
# 14                  0     7.0     10            0
# 15                  0     6.0     10            0
# 16                  0     6.0     10            0
# 17                  1     6.0     10            0
# 18                  1     6.5     10            0
# 19                  0     7.0     10            0
# 20                  1     6.5     10            0
# 21                  0     7.0     10            0
# 22                  0     9.0     10            0
# 23                  0     2.0      2            0
# 24                  0     2.0      2            0
# 25                  0     2.0      2            0
# 26                  0     2.0      2            0
# 27                  0     2.0      2            0
# 28                  0     2.0      2            0
# 29                  0     2.0      2            0
# ...               ...     ...    ...          ...
# 1248                0     1.0      1            0
# 1249                0     1.0      1            0
# 1250                0     1.0      1            0
# 1251                0     1.0      1            0
# 1252                0     1.0      1            0
# 1253                0     1.0      1            0
# 1254                0     1.0      1            0
# 1255                0     1.0      1            0
# 1256                0     1.0      1            0
# 1257                0     1.0      1            0
# 1258                0     1.0      1            0
# 1259                0     1.0      1            0
# 1260                0     1.0      1            0
# 1261                0     1.0      1            0
# 1262                0     1.0      1            0
# 1263                0     1.0      1            0
# 1264                0     1.0      1            0
# 1265                0     1.0      1            0
# 1266                0     1.0      1            0
# 1267                0     1.0      1            0
# 1268                0     1.0      1            0
# 1269                0     1.0      1            0
# 1270                0     1.0      1            0
# 1271                0     1.0      1            0
# 1391                0     9.5     10            0
# 1392                0    20.5     25            0
# 1393                0    25.5     30            0
# 1394                0    24.5     30            0
# 1395                1     9.5     10            0
# 1396                1     9.5     10            0
#
# [1278 rows x 10 columns]

# %%
new_df['Task']=new_df['Task'].str.lower()
# Out:
# C:\Users\praso\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df['Month']=new_df['Date'].dt.month
# Out:
# C:\Users\praso\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df['Month']=new_df['Month'].replace({3:8,4:8})
# Out:
# C:\Users\praso\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df.replace({'Swaastik':'Swaastick','Sushree':'Siddhishikha'},inplace=True)
# Out:
# C:\Users\praso\Anaconda3\lib\site-packages\pandas\core\frame.py:4042: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)

# %%
new_df=new_df[new_df['Student']!=""]
new_df=new_df[new_df['Student']!='Wrick']
new_df=new_df[new_df['Student']!='Nitish']
new_df=new_df[new_df['Student']!='Sudhanshu']

# %%
def duplicates_removal(task):
    temp=new_df[new_df['Task']==task]
    months=temp['Date'].dt.month.unique().tolist()
    indx=np.array([])
    for date,month in zip(temp['Date'].values,temp['Month'].values):
        mask_date=temp['Date']==date
        mask_month=temp['Month']==month
        d=temp[mask_date & mask_month].sort_values('Student')
        indx=np.append(indx,d[d.duplicated(subset='Student',keep='last')].index)
    temp_1=temp.drop(indx)
    return temp_1

# %%
my_df=duplicates_removal('ajkyaukhada')

# %%
knowledge_df=duplicates_removal('knowledge sharing')

# %%
my_df.shape
# Out:
# (901, 11)

# %%
t=knowledge_df[knowledge_df['Date']>'2019-08-14']

# %%
t.head()
# Out:
#      Id               Task                Date  Module                   Type  \
# 557   0  knowledge sharing 2019-08-14 04:39:38  Ritual  Consistency,Curiosity
# 558   0  knowledge sharing 2019-08-14 04:47:42  Ritual  Consistency,Curiosity
# 559   0  knowledge sharing 2019-08-14 05:21:39  Ritual  Consistency,Curiosity
# 586   0  knowledge sharing 2019-08-14 16:38:37  Ritual  Consistency,Curiosity
# 589   0  knowledge sharing 2019-08-14 17:17:39  Ritual  Consistency,Curiosity
#
#        Student  Late Submission  Points  Total  Task Winner  Month
# 557  Swaastick                0     2.0      2            0      8
# 558   Ujjainee                0     2.0      2            0      8
# 559    Prasoon                0     2.0      2            0      8
# 586    Surabhi                0     2.0      2            0      8
# 589      Dipam                0     2.0      2            0      8

# %%
t.shape
# Out:
# (77, 11)

# %%
sunday=['Arya','Anjali','Surabhi']
monday=['Kunal','Bhavna','Apurwa']
tuesday=['Purbita','Chandrima','Prasoon']
wednesday=['Roumyak','Kaushal','Ujjainee']
thursday=['Shakib','Dipam','Siddhishikha']
friday=['Shantanu','Durga','Sonali']
saturday=['Swaastick','Sharika','Vishal']

# %%
t['weekdays']=t['Date'].dt.strftime("%A")
# Out:
# C:\Users\praso\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def knowledge_cleaner(knowledge):
    indx=np.array([])
    c=0
    for c in range (0,len(t['weekdays'])):
        i=t['weekdays'].iloc[c]
        student=knowledge['Student'].iloc[c]
        idx=knowledge['Student'].index[c]
        if i=='Monday':
            if(student not in monday):
                indx=np.append(indx,idx)
        elif i=='Tuesday':
            if(student not in tuesday):
                indx=np.append(indx,idx)
        elif i=='Wednesday':
            if(student not in wednesday):
                indx=np.append(indx,idx)
        elif i=='Thursday':
            if(student not in thursday):
                indx=np.append(indx,idx)
        elif i=='Friday':
            if(student not in friday):
                indx=np.append(indx,idx)
        elif i=='Saturday':
            if(student not in saturday):
                indx=np.append(indx,idx)
        elif i=='Sunday':
            if(student not in sunday):
                indx=np.append(indx,idx)
        c+=1
    return indx

# %%
idx=knowledge_cleaner(t)
knowledge_df=knowledge_df.drop(idx)

# %%
len(knowledge_df)
# Out:
# 76

# %%
temp=new_df[new_df['Task']!='ajkyaukhada']
other_tasks=temp[temp['Task']!='knowledge sharing']

# %%
student_list=new_df['Student'].unique().tolist()

# %%
indx=np.array([])
for i in student_list:
    temp_df=other_tasks[other_tasks['Student']==i]
    indx=np.append(indx,temp_df[temp_df.duplicated(subset='Task',keep='last')].index)
other_tasks=other_tasks.drop(indx)

# %%
tasks=other_tasks.groupby('Student')['Points'].sum().reset_index()

# %%
myday_df=my_df.groupby('Student')['Points'].sum().reset_index()

# %%
knowledge_sharing=knowledge_df.groupby('Student')['Points'].sum().reset_index()

# %%
late_submission=other_tasks.groupby('Student')['Late Submission'].sum().reset_index()

# %%
wins=other_tasks.groupby('Student')['Task Winner'].sum().reset_index()

# %%
tot_task_score=other_tasks.groupby('Student')['Total'].sum().max()

# %% [markdown]
# # Merging all scores into one dataframe

# %%
final_df=myday_df.merge(knowledge_sharing,on='Student',how='outer')

# %%
final_df=final_df.merge(tasks,on='Student',how='outer')

# %%
final_df.insert(4,"Total Task Points",tot_task_score)

# %%
temp=final_df.drop(columns={'Total Task Points'})
final_df['Total Score'] = temp.sum(axis=1)

# %%
final_df=final_df.merge(late_submission,on='Student',how='outer')

# %%
final_df=final_df.merge(wins,on='Student',how='outer')

# %%
final_df.rename(columns={'Points_x':'MyDay Score','Points_y':'Knowledge Sharing Score','Late Submission':'Total Late Submissions','Task Winner':'Number of Wins','Points':'Task Score Achieved'},inplace=True)

# %% [markdown]
# # Analysis

# %%
final_df=final_df.sort_values(by='Total Score',ascending=False).reset_index(drop=True)
final_df
# Out:
#          Student  MyDay Score  Knowledge Sharing Score  Task Score Achieved  \
# 0          Kunal        104.0                     12.0                160.5
# 1       Ujjainee        102.0                     15.0                154.5
# 2        Purbita        102.0                     12.0                151.5
# 3         Shakib        100.0                     15.0                150.5
# 4        Surabhi        102.0                     11.0                151.5
# 5      Chandrima        102.0                     18.0                132.5
# 6         Sonali         98.0                      9.0                144.0
# 7         Vishal         98.0                      4.0                149.0
# 8          Dipam        102.0                     11.0                135.5
# 9        Sharika         99.0                      8.0                137.5
# 10  Siddhishikha         94.0                      7.0                139.5
# 11        Apurwa         95.0                      NaN                138.0
# 12         Durga         95.0                      5.0                129.5
# 13     Swaastick         78.0                      2.0                144.0
# 14       Prasoon         80.0                      9.0                125.5
# 15       Kaushal         88.0                      2.0                124.0
# 16       Roumyak         49.0                      NaN                142.0
# 17      Shantanu         41.0                      NaN                144.5
# 18          Arya         25.0                      NaN                137.5
# 19        Bhavna         34.0                      4.0                124.0
# 20        Anjali          5.0                      NaN                105.5
#
#     Total Task Points  Total Score  Total Late Submissions  Number of Wins
# 0                 180        276.5                       3               3
# 1                 180        271.5                       1               0
# 2                 180        265.5                       4               2
# 3                 180        265.5                       2               2
# 4                 180        264.5                       2               1
# 5                 180        252.5                       4               1
# 6                 180        251.0                       3               1
# 7                 180        251.0                       0               1
# 8                 180        248.5                       1               1
# 9                 180        244.5                       5               1
# 10                180        240.5                       5               0
# 11                180        233.0                       3               1
# 12                180        229.5                       3               1
# 13                180        224.0                      10               1
# 14                180        214.5                       5               0
# 15                180        214.0                       4               1
# 16                180        191.0                       3               2
# 17                180        185.5                       5               1
# 18                180        162.5                       8               2
# 19                180        162.0                       2               0
# 20                180        110.5                       1               0

# %%
p1=plt.figure(figsize=(20,7))
sns.countplot(x='Student',data=my_df)
plt.xlabel('Names', fontsize=20)
plt.ylabel('Numbers',fontsize=20)
plt.title("Myday",fontsize=30)
plt.show()

# %%
p2=plt.figure(figsize=(20,7))
sns.countplot(x='Student',data=knowledge_df)
plt.xlabel('Names', fontsize=20)
plt.ylabel('Numbers',fontsize=20)
plt.title("Knowledge Sharing",fontsize=30)
plt.show()

# %%
len(knowledge_df)
# Out:
# 76

# %%
p3=plt.figure(figsize=(20,7))
total=final_df.groupby('Student')['Task Score Achieved'].sum().sort_values(ascending=False)
total.plot.bar(x='Student',y='Task Score Achieved')
plt.xlabel('Student Names',fontsize=20)
plt.ylabel("Task Scores",fontsize=20)
plt.title("Task Score Graph",fontsize=30)
plt.show()

# %%
p4=plt.figure(figsize=(20,7))
total=final_df.groupby('Student')['Total Score'].sum().sort_values(ascending=False)
total.plot.bar(x='Student',y='Total Score')
plt.xlabel('Student Names',fontsize=20)
plt.ylabel("Total Scores",fontsize=20)
plt.title("Total Score Graph",fontsize=30)
plt.show()

# %%
len(t)
# Out:
# 77

# %%
len(knowledge_df)
# Out:
# 76

# %% [markdown]
# # Conversion to pdf

# %%
p1.savefig("myday.jpg",bbox_inches='tight')
p2.savefig("knowledge.jpg",bbox_inches='tight')
p3.savefig("task",bbox_inches='tight')
p4.savefig("score",bbox_inches='tight')

# %%
#pip install reportlab

# %%
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors

# %%
def report_creator(name):
    table=final_df[final_df['Student']==name]
    rank=table.index.values[0]+1
    total=table['Task Score Achieved'].iloc[0]
    late=table['Total Late Submissions'].iloc[0]
    win=table['Number of Wins'].iloc[0]
    myday=table['MyDay Score'].iloc[0]
    gyan=table['Knowledge Sharing Score'].iloc[0]
    table1=final_df.head(21)
    student=table1['Student'].values
    tot=table1['Total Score'].values
    my_canvas = canvas.Canvas("Result.pdf",pagesize=letter)
    my_canvas.setLineWidth(.3)
    my_canvas.drawImage("campusx.jpeg", 143, 730,width=52,height=50)
    my_canvas.setFont('Times-Bold', 20)
    my_canvas.drawString(200,750,'CAMPUSX RESULTS')
    my_canvas.setFont('Times-Roman', 14)
    my_canvas.drawString(50,700,'Hi , here are your results!!')
    my_canvas.drawString(55,670,"Leaderboard")
    my_canvas.setFont('Times-Bold', 13)
    my_canvas.drawString(55,650,"Name")
    my_canvas.drawString(175,650,"Total Score")
    my_canvas.drawImage("image.jpg",300,380,width=200,height=200)
    my_canvas.setFont('Times-Roman', 12)
    c=630
    for i,j in zip(student,tot):
        my_canvas.drawString(55,c,i)
        my_canvas.drawString(175,c,str(j))
        c-=15
    my_canvas.drawImage("myday.jpg", 20, 20,width=580,height=300)
    my_canvas.showPage()
    my_canvas.drawImage("knowledge.jpg", 20, 420,width=580,height=300)
    my_canvas.save()

# %%
students=final_df['Student'].unique().tolist()

# %% [markdown]
# # Sending pdf via email

# %%
email_user = config.email_user
email_password = config.email_password
email_send = config.email_send

subject = 'CampusX Results'

msg = MIMEMultipart()
msg['From'] = email_user
msg['To'] = ",".join(email_send)
msg['Subject'] = subject

body = 'Your Monthly Results'
msg.attach(MIMEText(body,'plain'))

filename='Result.pdf'
attachment  =open(filename,'rb')

part = MIMEBase('application','octet-stream')
part.set_payload((attachment).read())
encoders.encode_base64(part)
part.add_header('Content-Disposition',"attachment; filename= "+filename)

msg.attach(part)
text = msg.as_string()
for i in range(len(email_send)): 
    server = smtplib.SMTP('smtp.gmail.com', 587) 
    server.starttls() 
    server.login(email_user,email_password) 
    server.sendmail(email_user, email_send[i],text)
server.quit()
# Out:
# (221, b'2.0.0 closing connection v19sm70401pff.46 - gsmtp')
